# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Reading the semi-colan seperated file

# %%
df = pd.read_csv("C:/Users/Naman Kapoor/Downloads/winequality-red.csv", delimiter=";")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ## Exploratory Analysis

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1599, step=1)

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.loc[[1,2]]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 1      9.8        5
# 2      9.8        5

# %%
df.iloc[1:3]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 1      9.8        5
# 2      9.8        5

# %%
df.loc[df['quality']>5,['quality']]
# Out:
#       quality
# 3           6
# 7           7
# 8           7
# 16          7
# 19          6
# ...       ...
# 1592        6
# 1593        6
# 1595        6
# 1596        6
# 1598        6
#
# [855 rows x 1 columns]

# %%
df[df['quality']>5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 16              8.5              0.28         0.56             1.8      0.092
# 19              7.9              0.32         0.51             1.8      0.341
# ...             ...               ...          ...             ...        ...
# 1592            6.3              0.51         0.13             2.3      0.076
# 1593            6.8              0.62         0.08             1.9      0.068
# 1595            5.9              0.55         0.10             2.2      0.062
# 1596            6.3              0.51         0.13             2.3      0.076
# 1598            6.0              0.31         0.47             3.6      0.067
#
# ...

# %%
df.loc[df['alcohol']==10.0,['alcohol']]
# Out:
#       alcohol
# 7        10.0
# 58       10.0
# 116      10.0
# 146      10.0
# 162      10.0
# ...       ...
# 1461     10.0
# 1466     10.0
# 1468     10.0
# 1494     10.0
# 1524     10.0
#
# [67 rows x 1 columns]

# %%
df.loc[df['citric acid']==0.56,['citric acid']]
# Out:
#       citric acid
# 3            0.56
# 16           0.56
# 130          0.56
# 241          0.56
# 481          0.56
# 1076         0.56
# 1080         0.56
# 1371         0.56

# %%
df.loc[df['residual sugar']==1.9,['residual sugar']]
# Out:
#       residual sugar
# 0                1.9
# 3                1.9
# 4                1.9
# 28               1.9
# 62               1.9
# ...              ...
# 1537             1.9
# 1542             1.9
# 1565             1.9
# 1569             1.9
# 1593             1.9
#
# [117 rows x 1 columns]

# %%
subset= df.loc[:,'alcohol']
subset
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1594    10.5
# 1595    11.2
# 1596    11.0
# 1597    10.2
# 1598    11.0
# Name: alcohol, Length: 1599, dtype: float64

# %%
subset1 = df.loc[:,"quality"]
subset1
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# ## Plotting

# %%
df.hist(bins = 40, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>],
#        [<AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free sulfur dioxide'}>],
#        [<AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %%
df.hist(bins=20,figsize=(20,15))
plt.savefig("hist_1.png")

# %% [markdown]
# The distributions of density and pH are nearly normally distributed. The distributions of fixed acidity, volatile acidity, residual sugar, sulphates,alcohol and free sulfur dioxide are right skewed. The distributions for chlorides,  citric acid, and quality have unknown distributions. Based on the histograms, we might need to normalize or standardize the features that have right skewed or unknown distributions for prediction.
#
#
# right skewed data With right-skewed distribution (also known as "positively skewed" distribution), most data falls to the right, or positive side, of the graph's peak. Thus, the histogram skews in such a way that its right side (or "tail") is longer than its left side.
#
#
#
#
# Data skewed to the right is usually a result of a lower boundary in a data set (whereas data skewed to the left is a result of a higher boundary). So if the data set's lower bounds are extremely low relative to the rest of the data, this will cause the data to skew right.
#
# Another cause of skewness is start-up effects. For example, if a procedure initially has a lot of successes during a long start-up period, this could create a positive skew on the data. (On the opposite hand, a start-up period with several initial failures can negatively skew data.)

# %%
#Subsetting the dataset by removing non/weak correlated predictors{range: -0.15<x<0.15,{use double brackets when selecting multiple components}
df = df[["volatile acidity","citric acid","total sulfur dioxide","density","sulphates","alcohol","quality"]]
df1 = df[["volatile acidity","citric acid","total sulfur dioxide","density","sulphates","alcohol"]]

# %%
labels= ["VA","CA","totalSD","density","sulphates","alcohol"]
bp = plt.boxplot(df1, labels = labels ,widths = 0.6, patch_artist = True)
plt.savefig("boxplot_1.png")

# %%
df.corr()["quality"]
# Out:
# volatile acidity       -0.390558
# citric acid             0.226373
# total sulfur dioxide   -0.185100
# density                -0.174919
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
##Using pandas.plotting function to plot scatter graphs
from pandas.plotting import scatter_matrix
scatter_matrix((df),figsize=(20,20))
plt.savefig("scatterplot_1.png", bbox_inches="tight")
plt.show()

# %%
#Multimodal Data Visulaizations
#(heatmap)
import seaborn as sns
sns.heatmap(df.corr())
plt.savefig("heatmap.png")
plt.show()

# %%
sns.countplot(df['quality'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
df.corrwith(df.quality).plot.bar(
        figsize = (20, 10), title = "Correlation with quality", fontsize = 15,
        rot = 45, grid = True)
plt.savefig("corrbarplot.png")

# %%
#(scatterplots)
plt.scatter(df["quality"],df["alcohol"])

# %%
plt.scatter(df["volatile acidity"],df["citric acid"])

# %%
plt.scatter(df["volatile acidity"],df["sulphates"])

# %%
#pre processing the data
#All the column will be transformed except the 'quality' variable

from sklearn.preprocessing import MinMaxScaler
cols_to_norm = ["volatile acidity","citric acid","total sulfur dioxide","density","sulphates","alcohol"]
df[cols_to_norm]= MinMaxScaler().fit_transform(df[cols_to_norm])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
#train test split
y = df['quality']
x = df[["volatile acidity","citric acid","total sulfur dioxide","density","sulphates","alcohol"]]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=45)

# %%
x_test
# Out:
#       volatile acidity  citric acid  total sulfur dioxide   density  \
# 69            0.400685         0.05              0.045936  0.450073
# 1541          0.089041         0.29              0.151943  0.483847
# 368           0.150685         0.52              0.243816  0.714391
# 559           0.239726         0.49              0.144876  0.883260
# 249           0.369863         0.00              0.060071  0.604258
# ...                ...          ...                   ...       ...
# 1426          0.075342         0.37              0.190813  0.516153
# 179           0.335616         0.14              0.127208  0.501468
# 417           0.315068         0.12              0.416961  0.406021
# 1298          0.328767         0.00              0.042403  0.135095
# 1062          0.178082         0.44              0.031802  0.406021
#
#       sulphates   alcohol
# 69     0.371257  0.323077
# 1541   0.257485  0.384615
# 368    0.185629  0.153846
# 559    0.209581  0.661538
# ...

# %% [markdown]
# ## Applying different Models

# %%
#linear regression 
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n',lm.coef_)
# Out:
# Coefficients:
#  [-1.56832849 -0.00875114 -0.61049677  0.22902793  1.26219967  2.14390241]

# %%
predictions = lm.predict(x_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Xtest')
plt.ylabel('predicted y')
# Out:
# Text(0, 0.5, 'predicted y')

# %%
#evaluating the model
from sklearn import metrics
print('MSE:', metrics.mean_squared_error(y_test,predictions))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MSE: 0.45124880713910837
# RMSE 0.6717505542529223

# %%
#Applying polynomial regression
from sklearn.preprocessing import PolynomialFeatures
rmse_dict = {}

for i in range(2,5):    
    poly = PolynomialFeatures(degree=i)
    x_poly_train = poly.fit_transform(x_train)
    x_poly_test = poly.fit_transform(x_test)
    poly.fit(x_poly_train,y_train)
    lin2 = LinearRegression()
    lin2.fit(x_poly_train,y_train)
    predictions_1 = lin2.predict(x_poly_test)
    rmse = np.sqrt(metrics.mean_squared_error(y_test,predictions_1))
    rmse_dict[i] = rmse

# %%
rmse_dict
# Out:
# {2: 0.6558470485754802, 3: 0.6717520786201278, 4: 1.6471676251612757}

# %%
plt.plot(rmse_dict.keys(), rmse_dict.values(), marker = 'o', linestyle='dotted')
plt.xlabel("Polynomial order:(Dictionary keys)")
plt.ylabel("Rmse values:(Dictionary values)")
plt.title("Rmse values using Polynomial Regression")
plt.savefig("ploy_fig.png")

# %%
#cross validation 
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(lin2,df1,df['quality'],cv=10)
print(scores)
# Out:
# [-0.30540451  0.35323384  0.23840597  0.36257422  0.04637622  0.38246307
#   0.29242958  0.37121644  0.26801619  0.26513431]

# %% [markdown]
# ## Decision tree and Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rnd = RandomForestClassifier()

# %%
rnd.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred_test = rnd.predict(x_test)

# %%
y_pred_train = rnd.predict(x_train)

# %%
print("Accuracy Score is:",accuracy_score(y_pred_test,y_test))
# Out:
# Accuracy Score is: 0.73125

# %%
print("Accuracy Score is:",accuracy_score(y_pred_train,y_train))
# Out:
# Accuracy Score is: 1.0

# %%
#Cross Validation
#Cross validation (CV) is one of the technique used to test the effectiveness of a machine learning models, it is also a re-sampling procedure used to evaluate a model if we have a limited data. To perform CV we need to keep aside a sample/portion of the data on which is not used to train the model, later use this sample for testing/validating.

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(rnd,df1,df['quality'],cv=10)

# %%
print(scores)
# Out:
# [0.50625    0.59375    0.56875    0.59375    0.575      0.6375
#  0.60625    0.53125    0.60625    0.55974843]

# %%
plt.title("Cross Validation Scores")
plt.xlabel("Cross Value K")
plt.ylabel("Scores")
plt.plot(scores, marker = 'o',linestyle = 'dotted')
plt.savefig("randomfor_cv.png")

# %%
##Context: The cross-validation method and the holdout method (train-test split) are seen as two methods to evaluate the model performance. The goal of this evaluation is to obtain an estimate of the generalization (or, test) error.Summary: If the accuracy from the cross-validation method is less than the accuracy from the holdout method, it indicates model overfitting.Explanation: When the test error is estimated by the holdout method, the data is split into the training and holdout samples. However, this split may induce a bias since there's no guarantee of a randomness within the training and test samples even if the whole dataset is considered a random sample. In order to mitigate this bias we can average the test error stemming from different test samples. This is precisely what cross-validation does - it rotates the test sample across the whole dataset and for every test sample, the remaining dataset becomes the training sample. For each split, the test error is computed after fitting the model over the corresponding training sample. The test errors from each split are averaged to obtain the average test error, or the cross-validated error.

# %%
#applying baggingboth bagging and pasting allow training instances to be sampled sev‐eral times across multiple predictors, but only bagging allows training instances to besampled several times for the same predictor.

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
lst_new = []
import numpy as np
for i in np.arange(100,600,100):
     bag_clf = BaggingClassifier(
     DecisionTreeClassifier(), n_estimators=i,
     max_samples=100, bootstrap=True, n_jobs=-1)
     bag_clf.fit(x_train,y_train)
     predictions_1 = bag_clf.predict(x_test)
     rmse = np.sqrt(metrics.mean_squared_error(y_test,predictions_1))
     lst_new.append(rmse)

# %%
lst_new
# Out:
# [0.7224091638399944,
#  0.7071067811865476,
#  0.724568837309472,
#  0.7026734661277598,
#  0.7048936089935842]

# %%
plt.plot(np.arange(100,600,100), lst_new, marker ='o', linestyle = 'dotted')#np.arange gives the range of values from 100 to 600 with 100 steps.
plt.title('Rmse values using Bagging method')
plt.xlabel("estimators")
plt.ylabel("Rmse values")
plt.savefig("RMSEBagging.png")

# %%
bag_clf.fit(x_train,y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(), max_samples=100,
#                   n_estimators=500, n_jobs=-1)

# %%
y_predd = bag_clf.predict(x_test)

# %%
accuracy_1 = accuracy_score(y_test,y_predd)

# %%
bag_clf.oob_score_
# Out:
# 0.602814698983581

# %%
print("Accuracy score is:", accuracy_1 )
# Out:
# Accuracy score is: 0.64375

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_clf = AdaBoostClassifier(
 DecisionTreeClassifier(max_depth=10), n_estimators=125,
 algorithm="SAMME.R", learning_rate=0.5)
ada_clf.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=10),
#                    learning_rate=0.5, n_estimators=125)

# %%
y_pred_ada = ada_clf.predict(x_test)

# %%
accuracy_2 = accuracy_score(y_test,y_pred_ada)

# %%
print("Accuracy score is:", accuracy_2)
# Out:
# Accuracy score is: 0.69375
